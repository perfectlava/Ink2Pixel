# %%
from pipeline import DocumentDigitizerPipeline

# %%
pipeline = DocumentDigitizerPipeline()
result_path = pipeline.process_document("examples/examples/output/original.jpg", output_format="md")
# Out:
# ✔ Model loaded from /Users/user/development/Projects/Ink2Pixel/hand_writing_model/checkpoints/best.pth
