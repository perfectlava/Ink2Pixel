# %%
from got_ocr_pipeline import GotOcrDigitizer


pipeline = GotOcrDigitizer()
result = pipeline.process_document("../testing_images/bot_writing.png", output_format="md")
print(result)
# Out:
# Loading GOT-OCR 2.0... (This is very fast)
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# Model loaded successfully!
# An error occurred during OCR: CUDA error: no kernel image is available for execution on the device
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
# from qwen_pipeline import QwenDocumentDigitizer


# pipeline = QwenDocumentDigitizer()
# result = pipeline.process_document("../envision.jpg", output_format="md")
# print(result)
# Out:
# Loading Qwen2.5-VL... This may take a moment.
# ...
# Loading weights: 100%|██████████| 729/729 [00:00<00:00, 4332.36it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.
# Model loaded successfully!
# Envision,
# Create,
# and Believe
# in your own Universe,
# and the Universe will
# form around
# YOU.
